# %%
import os

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow import lite
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D
from keras.callbacks import ModelCheckpoint
from keras.metrics import Precision, Recall
from keras.models import load_model

from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support

# %%
batch_size = 32
image_height = 512
image_width = 512
epoch = 48

# %%
train_path = 'Lung/train'
test_path = 'Lung/test'
val_path = 'Lung/val'

# %%
def plotting_images(item_dir, num_imgs=5):
    all_item_dirs = os.listdir(item_dir)
    item_files = [os.path.join(item_dir, file) for file in all_item_dirs][:num_imgs]

    plt.figure(figsize=(10, 10))
    for idx, img_path in enumerate(item_files):
        plt.subplot(5, 5, idx+1)
        img = plt.imread(img_path)
        plt.axis('off')
        plt.imshow(img)

    plt.tight_layout()

# %%
plotting_images("Lung/train/Covid")

# %%
plotting_images("Lung/train/Lung_Opacity")

# %%
plotting_images("Lung/train/Normal")

# %%
plotting_images("Lung/train/Viral_Pneumonia")

# %%
train_datagen = ImageDataGenerator(rescale=1/255)
valid_datagen = ImageDataGenerator(rescale=1/255)
test_datagen = ImageDataGenerator(rescale=1/255)

# %%
train_dataset = train_datagen.flow_from_directory(train_path,
                                                  target_size=(image_height, image_width),
                                                  color_mode='grayscale', 
                                                  class_mode='categorical', 
                                                  batch_size= batch_size,
                                                  )

test_dataset = test_datagen.flow_from_directory(test_path,
                                                target_size=(image_height, image_width),
                                                class_mode='categorical',
                                                color_mode='grayscale',
                                                batch_size= batch_size,
                                                shuffle=False
                                                )

valid_dataset = valid_datagen.flow_from_directory(val_path,
                                                  target_size=(image_height, image_width),
                                                  class_mode='categorical',
                                                  batch_size= batch_size,
                                                  color_mode='grayscale',
                                                  )
# Out:
# Found 16930 images belonging to 4 classes.
# Found 2119 images belonging to 4 classes.
# Found 2116 images belonging to 4 classes.

# %%
checkpoint = ModelCheckpoint("Training_data_Lung-1.h5", mode='auto', save_freq=1)

# %%
model = Sequential([
  
    Conv2D(32,(3,3),strides=(1, 1),activation='relu',padding='same', input_shape=train_dataset.image_shape), 
    MaxPooling2D(pool_size=(2,2)),
    
    Conv2D(64,(3,3),strides=(1, 1) ,padding='same',activation='relu'),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(128,(3,3),strides=(1, 1),padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(256,(3,3),strides=(1, 1),padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),

    Flatten(),

    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(4, activation='softmax'),
 
])

# %%
METRICS = [
        'accuracy',
        Precision(name='precision'),
        Recall(name='recall')
    ]

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=METRICS)

# %%
model_fit = model.fit(train_dataset,
                      validation_data=valid_dataset,
                      steps_per_epoch=10,
                      epochs = epoch,
                      callbacks=[checkpoint])
# Out:
# Epoch 1/48
# 10/10 [==============================] - 284s 30s/step - loss: 1.9963 - accuracy: 0.3469 - precision: 0.3617 - recall: 0.1063 - val_loss: 1.3150 - val_accuracy: 0.4816 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/48
# 10/10 [==============================] - 271s 29s/step - loss: 1.2408 - accuracy: 0.4500 - precision: 0.5294 - recall: 0.1406 - val_loss: 1.2583 - val_accuracy: 0.4816 - val_precision: 0.5395 - val_recall: 0.4031
# Epoch 3/48
# 10/10 [==============================] - 271s 29s/step - loss: 1.1798 - accuracy: 0.5219 - precision: 0.5200 - recall: 0.2844 - val_loss: 1.2155 - val_accuracy: 0.4816 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/48
# 10/10 [==============================] - 274s 29s/step - loss: 1.1893 - accuracy: 0.5000 - precision: 0.5043 - recall: 0.1813 - val_loss: 1.2810 - val_accuracy: 0.4882 - val_precision: 0.7759 - val_recall: 0.3110
# Epoch 5/48
# 10/10 [==============================] - 238s 25s/step - loss: 1.1268 - accuracy: 0.5094 - precision: 0.6259 - recall: 0.2719 - val_loss: 1.1944 - val_accuracy: 0.4816 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/48
# 10/10 [==============================] - 177s 19s/step - loss: 1.1183 - accuracy: 0.4375 - precision: 0.5735 - recall: 0.2438 - val_loss: 1.2087 - val_accuracy: 0.4055 - val_precision: 0.5152 - val_recall: 0.1602
# Epoch 7/48
# 10/10 [==============================] - 177s 19s/step - loss: 1.0557 - accuracy: 0.5031 - precision: 0.6581 - recall: 0.3187 - val_loss: 0.9415 - val_accuracy: 0.6276 - val_precision: 0.7310 - val_recall: 0.4509
# Epoch 8/48
# 10/10 [==============================] - 176s 19s/step - loss: 0.9514 - accuracy: 0.5844 - precision: 0.6473 - recall: 0.4531 - val_loss: 0.9511 - val_accuracy: 0.6068 - val_precision: 0.6787 - val_recall: 0.5222
# Epoch 9/48
# 10/10 [==============================] - 178s 19s/step - loss: 0.8763 - accuracy: 0.6375 - precision: 0.7406 - recall: 0.4906 - val_loss: 1.1691 - val_accuracy: 0.6096 - val_precision: 0.6189 - val_recall: 0.5955
# Epoch 10/48
# 10/10 [==============================] - 184s 20s/step - loss: 1.0135 - accuracy: 0.5750 - precision: 0.6411 - recall: 0.4187 - val_loss: 0.8559 - val_accuracy: 0.6229 - val_precision: 0.7045 - val_recall: 0.5128
# Epoch 11/48
# 10/10 [==============================] - 283s 30s/step - loss: 0.9323 - accuracy: 0.5793 - precision: 0.6359 - recall: 0.4517 - val_loss: 1.0319 - val_accuracy: 0.6096 - val_precision: 0.8559 - val_recall: 0.0926
# Epoch 12/48
# 10/10 [==============================] - 288s 31s/step - loss: 0.8745 - accuracy: 0.6531 - precision: 0.7150 - recall: 0.4625 - val_loss: 0.8943 - val_accuracy: 0.6139 - val_precision: 0.6890 - val_recall: 0.4565
# Epoch 13/48
# 10/10 [==============================] - 257s 27s/step - loss: 0.8618 - accuracy: 0.6438 - precision: 0.7016 - recall: 0.5656 - val_loss: 0.8118 - val_accuracy: 0.6621 - val_precision: 0.7082 - val_recall: 0.6011
# Epoch 14/48
# 10/10 [==============================] - 274s 29s/step - loss: 0.8603 - accuracy: 0.6219 - precision: 0.6590 - recall: 0.5375 - val_loss: 0.8377 - val_accuracy: 0.6654 - val_precision: 0.7641 - val_recall: 0.4792
# Epoch 15/48
# 10/10 [==============================] - 268s 29s/step - loss: 0.7657 - accuracy: 0.7000 - precision: 0.7356 - recall: 0.6000 - val_loss: 0.8216 - val_accuracy: 0.6503 - val_precision: 0.6958 - val_recall: 0.5870
# Epoch 16/48
# 10/10 [==============================] - 279s 30s/step - loss: 0.8671 - accuracy: 0.6219 - precision: 0.6694 - recall: 0.5188 - val_loss: 0.8535 - val_accuracy: 0.6371 - val_precision: 0.7285 - val_recall: 0.5491
# Epoch 17/48
# 10/10 [==============================] - 279s 30s/step - loss: 0.8145 - accuracy: 0.6438 - precision: 0.7197 - recall: 0.5375 - val_loss: 0.8672 - val_accuracy: 0.6489 - val_precision: 0.6813 - val_recall: 0.6243
# Epoch 18/48
# 10/10 [==============================] - 212s 22s/step - loss: 0.8308 - accuracy: 0.6531 - precision: 0.7247 - recall: 0.5594 - val_loss: 0.8652 - val_accuracy: 0.6635 - val_precision: 0.6933 - val_recall: 0.6304
# Epoch 19/48
# 10/10 [==============================] - 170s 18s/step - loss: 0.8785 - accuracy: 0.6438 - precision: 0.6708 - recall: 0.5094 - val_loss: 0.9298 - val_accuracy: 0.5463 - val_precision: 0.6150 - val_recall: 0.4258
# Epoch 20/48
# 10/10 [==============================] - 171s 18s/step - loss: 0.8979 - accuracy: 0.6156 - precision: 0.6872 - recall: 0.5219 - val_loss: 0.7654 - val_accuracy: 0.6668 - val_precision: 0.7614 - val_recall: 0.5747
# Epoch 21/48
# 10/10 [==============================] - 201s 22s/step - loss: 0.7576 - accuracy: 0.6750 - precision: 0.7293 - recall: 0.6062 - val_loss: 0.7291 - val_accuracy: 0.7098 - val_precision: 0.7715 - val_recall: 0.6096
# Epoch 22/48
# 10/10 [==============================] - 182s 19s/step - loss: 0.7500 - accuracy: 0.7094 - precision: 0.7454 - recall: 0.6313 - val_loss: 0.7176 - val_accuracy: 0.6909 - val_precision: 0.7349 - val_recall: 0.6432
# Epoch 23/48
# 10/10 [==============================] - 172s 18s/step - loss: 0.7705 - accuracy: 0.6906 - precision: 0.7052 - recall: 0.5906 - val_loss: 0.8738 - val_accuracy: 0.6503 - val_precision: 0.6937 - val_recall: 0.5737
# Epoch 24/48
# 10/10 [==============================] - 169s 18s/step - loss: 0.7849 - accuracy: 0.6969 - precision: 0.7500 - recall: 0.6187 - val_loss: 0.7581 - val_accuracy: 0.6796 - val_precision: 0.7188 - val_recall: 0.6078
# Epoch 25/48
# 10/10 [==============================] - 187s 20s/step - loss: 0.6800 - accuracy: 0.7312 - precision: 0.7730 - recall: 0.6812 - val_loss: 0.8311 - val_accuracy: 0.6560 - val_precision: 0.7045 - val_recall: 0.5421
# Epoch 26/48
# 10/10 [==============================] - 177s 19s/step - loss: 0.6519 - accuracy: 0.7594 - precision: 0.7964 - recall: 0.6969 - val_loss: 0.6709 - val_accuracy: 0.7278 - val_precision: 0.7634 - val_recall: 0.6815
# Epoch 27/48
# 10/10 [==============================] - 173s 18s/step - loss: 0.6951 - accuracy: 0.7281 - precision: 0.7527 - recall: 0.6562 - val_loss: 0.6766 - val_accuracy: 0.7075 - val_precision: 0.7515 - val_recall: 0.6659
# Epoch 28/48
# 10/10 [==============================] - 173s 18s/step - loss: 0.6804 - accuracy: 0.7312 - precision: 0.7927 - recall: 0.6812 - val_loss: 0.6366 - val_accuracy: 0.7528 - val_precision: 0.7870 - val_recall: 0.7070
# Epoch 29/48
# 10/10 [==============================] - 180s 19s/step - loss: 0.7047 - accuracy: 0.6938 - precision: 0.7464 - recall: 0.6531 - val_loss: 0.6287 - val_accuracy: 0.7656 - val_precision: 0.8166 - val_recall: 0.6819
# Epoch 30/48
# 10/10 [==============================] - 190s 20s/step - loss: 0.8612 - accuracy: 0.7094 - precision: 0.7544 - recall: 0.6625 - val_loss: 0.6054 - val_accuracy: 0.7670 - val_precision: 0.8213 - val_recall: 0.6777
# Epoch 31/48
# 10/10 [==============================] - 177s 19s/step - loss: 0.5761 - accuracy: 0.7688 - precision: 0.8258 - recall: 0.7406 - val_loss: 0.9889 - val_accuracy: 0.6101 - val_precision: 0.6291 - val_recall: 0.5723
# Epoch 32/48
# 10/10 [==============================] - 206s 22s/step - loss: 0.6883 - accuracy: 0.7063 - precision: 0.7482 - recall: 0.6500 - val_loss: 0.6197 - val_accuracy: 0.7609 - val_precision: 0.7953 - val_recall: 0.7160
# Epoch 33/48
# 10/10 [==============================] - 166s 18s/step - loss: 0.6192 - accuracy: 0.7625 - precision: 0.8049 - recall: 0.7219 - val_loss: 0.6741 - val_accuracy: 0.7391 - val_precision: 0.7721 - val_recall: 0.7141
# Epoch 34/48
# 10/10 [==============================] - 168s 18s/step - loss: 0.5328 - accuracy: 0.7937 - precision: 0.8209 - recall: 0.7594 - val_loss: 0.6408 - val_accuracy: 0.7429 - val_precision: 0.7720 - val_recall: 0.7089
# Epoch 35/48
# 10/10 [==============================] - 172s 18s/step - loss: 0.6482 - accuracy: 0.7563 - precision: 0.7785 - recall: 0.7031 - val_loss: 1.7214 - val_accuracy: 0.3814 - val_precision: 0.3830 - val_recall: 0.3634
# Epoch 36/48
# 10/10 [==============================] - 179s 19s/step - loss: 0.7548 - accuracy: 0.6969 - precision: 0.7473 - recall: 0.6562 - val_loss: 0.5713 - val_accuracy: 0.7807 - val_precision: 0.8261 - val_recall: 0.7117
# Epoch 37/48
# 10/10 [==============================] - 192s 20s/step - loss: 0.5479 - accuracy: 0.7969 - precision: 0.8271 - recall: 0.7625 - val_loss: 0.5934 - val_accuracy: 0.7604 - val_precision: 0.7859 - val_recall: 0.7235
# Epoch 38/48
# 10/10 [==============================] - 180s 19s/step - loss: 0.5795 - accuracy: 0.7688 - precision: 0.7895 - recall: 0.7031 - val_loss: 0.6344 - val_accuracy: 0.7557 - val_precision: 0.7807 - val_recall: 0.7098
# Epoch 39/48
# 10/10 [==============================] - 172s 18s/step - loss: 0.6010 - accuracy: 0.7563 - precision: 0.7847 - recall: 0.7063 - val_loss: 0.6879 - val_accuracy: 0.7250 - val_precision: 0.7467 - val_recall: 0.7009
# Epoch 40/48
# 10/10 [==============================] - 168s 18s/step - loss: 0.5549 - accuracy: 0.7719 - precision: 0.8116 - recall: 0.7406 - val_loss: 0.5338 - val_accuracy: 0.7935 - val_precision: 0.8291 - val_recall: 0.7543
# Epoch 41/48
# 10/10 [==============================] - 170s 18s/step - loss: 0.5182 - accuracy: 0.7937 - precision: 0.8079 - recall: 0.7625 - val_loss: 0.5424 - val_accuracy: 0.7982 - val_precision: 0.8164 - val_recall: 0.7713
# Epoch 42/48
# 10/10 [==============================] - 183s 20s/step - loss: 0.6020 - accuracy: 0.7844 - precision: 0.8034 - recall: 0.7281 - val_loss: 0.5197 - val_accuracy: 0.8053 - val_precision: 0.8427 - val_recall: 0.7647
# Epoch 43/48
# 10/10 [==============================] - 199s 21s/step - loss: 0.5593 - accuracy: 0.7812 - precision: 0.8041 - recall: 0.7437 - val_loss: 0.4839 - val_accuracy: 0.8129 - val_precision: 0.8363 - val_recall: 0.7750
# Epoch 44/48
# 10/10 [==============================] - 175s 18s/step - loss: 0.5879 - accuracy: 0.7688 - precision: 0.8179 - recall: 0.7437 - val_loss: 0.5049 - val_accuracy: 0.8006 - val_precision: 0.8238 - val_recall: 0.7732
# Epoch 45/48
# 10/10 [==============================] - 162s 17s/step - loss: 0.5164 - accuracy: 0.7812 - precision: 0.8013 - recall: 0.7563 - val_loss: 0.5316 - val_accuracy: 0.7935 - val_precision: 0.8174 - val_recall: 0.7656
# Epoch 46/48
# 10/10 [==============================] - 171s 18s/step - loss: 0.5059 - accuracy: 0.8250 - precision: 0.8399 - recall: 0.8031 - val_loss: 0.5186 - val_accuracy: 0.7963 - val_precision: 0.8283 - val_recall: 0.7637
# Epoch 47/48
# 10/10 [==============================] - 265s 29s/step - loss: 0.5473 - accuracy: 0.8000 - precision: 0.8167 - recall: 0.7656 - val_loss: 0.5969 - val_accuracy: 0.7571 - val_precision: 0.7883 - val_recall: 0.7127
# Epoch 48/48
# 10/10 [==============================] - 294s 31s/step - loss: 0.5440 - accuracy: 0.8062 - precision: 0.8215 - recall: 0.7625 - val_loss: 0.4938 - val_accuracy: 0.8091 - val_precision: 0.8355 - val_recall: 0.7680

# %%
model.save('Training_data_Lung-1.h5')

# %%
tf_model = load_model("Training_data_Lung-1.h5")
converter = lite.TFLiteConverter.from_keras_model(tf_model)
converter.optimizations = [lite.Optimize.DEFAULT]
tflite_model = converter.convert()
with open("Training_data_Lung_lite.tflite", 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\VISHAL~1\AppData\Local\Temp\tmp5e3m5hws\assets
# INFO:tensorflow:Assets written to: C:\Users\VISHAL~1\AppData\Local\Temp\tmp5e3m5hws\assets

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy','precision','recall', 'loss']):
    ax[i].plot(model_fit.history[met])
    ax[i].plot(model_fit.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
predictions = model.predict(test_dataset)
# Out:
# 67/67 [==============================] - 109s 2s/step

# %%
diseases_labels = []

for key, value in train_dataset.class_indices.items():
   diseases_labels.append(key)

# %%
def evaluate(actual, predictions):
  pre = []
  for i in predictions:
    pre.append(np.argmax(i))

  accuracy = (pre == actual).sum() / actual.shape[0]
  print(f'Accuracy: {accuracy}')

  precision, recall, f1_score, _ = precision_recall_fscore_support(actual, pre, average='macro')
  print(f'Precision: {precision}')
  print(f'Recall: {recall}')
  print(f'F1_score: {f1_score}')

  fig, ax = plt.subplots(figsize=(5,5))
  conf_mat = confusion_matrix(actual, pre)
  sns.heatmap(conf_mat, annot=True, fmt='.0f', xticklabels=diseases_labels, yticklabels=diseases_labels).set_title('Confusion Matrix Heat map')
  plt.show()

# %%
evaluate(test_dataset.classes,predictions)
# Out:
# Accuracy: 0.7928268050967437
# Precision: 0.8309873797642294
# Recall: 0.7724784807351639
# F1_score: 0.7927383688723005

# %%
model.evaluate(test_dataset)
# Out:
# 67/67 [==============================] - 106s 2s/step - loss: 0.5038 - accuracy: 0.7928 - precision: 0.8287 - recall: 0.7555
# [0.5037781000137329,
#  0.7928268313407898,
#  0.8286749720573425,
#  0.7555450797080994]
